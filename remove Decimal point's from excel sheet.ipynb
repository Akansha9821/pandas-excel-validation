# %%
import pandas as pd
media_combination = pd.read_excel('weekly.xlsx', engine='openpyxl', sheet_name="Media Combinations")

# %%
media_combination
# Out:
#                       Media Variable Dependent Product Curve Type  \
# 0    2020 Total US Cinema Cinema S90               S60   S-Origin
# 1    2020 Total US Cinema Cinema S90               S90   S-Shaped
# 2    2020 Total US Cinema Cinema S90               V60   S-Shaped
# 3    2020 Total US Cinema Cinema S90               V90   S-Shaped
# 4    2020 Total US Cinema Cinema S90              XC40     Linear
# ..                               ...               ...        ...
# 599    2020 Total US TV Spot TV XC90               V60   S-Shaped
# 600    2020 Total US TV Spot TV XC90               V90   S-Shaped
# 601    2020 Total US TV Spot TV XC90              XC40   S-Shaped
# 602    2020 Total US TV Spot TV XC90              XC60   S-Shaped
# 603    2020 Total US TV Spot TV XC90              XC90   S-Origin
#
#      S-Shaped-Alpha  S-Shaped - Beta  S-Shaped Weekly Max Activity  \
# 0               NaN              NaN                           NaN
# ...

# %%
media_combination.columns
# Out:
# Index(['Media Variable', 'Dependent Product', 'Curve Type', 'S-Shaped-Alpha',
#        'S-Shaped - Beta', 'S-Shaped Weekly Max Activity',
#        'S-Shaped Weekly Max Activity (%)', 'S-Origin - Alpha',
#        'S-Origin - Beta', 'S-Origin Weekly Max Activity',
#        'S-Origin Weekly Max Activity (%)', 'Power - Alpha',
#        'Neg-Exp - Weekly Max Activity', 'Neg-Exp - Weekly Max Activity (%)',
#        'Moving Average - Number of Weeks', 'Moving Average - MA Offset',
#        'Decay', 'Lag', 'Weekly Coefficient'],
#       dtype='object')

# %%
def remove_weekly_decimal_point(media_combination= None, media_combination_gred = None, non_media_combination=None, non_media_combination_gred=None):
    if not media_combination.empty:
        for col in media_combination[media_combination.columns[3]]:
            print(col)

# %%
remove_weekly_decimal_point(media_combination)
# Out:
# nan
# 0.94
# 0.935
# 1.0
# nan
# 0.9
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 0.86
# 0.93
# 0.925
# 0.925
# nan
# 0.835
# nan
# nan
# 0.85
# 0.925
# 0.925
# nan
# 0.835
# nan
# nan
# 0.93
# nan
# nan
# nan
# 0.835
# nan
# nan
# 0.93
# 0.925
# 0.925
# nan
# 0.835
# nan
# nan
# 0.93
# 0.925
# 0.925
# nan
# 0.95
# nan
# nan
# 0.93
# 0.925
# 0.925
# nan
# 0.835
# nan
# nan
# nan
# 0.875
# 0.875
# 0.95
# nan
# nan
# nan
# nan
# 0.875
# 0.875
# 0.95
# nan
# nan
# nan
# nan
# 0.875
# 0.875
# 0.95
# nan
# nan
# nan
# nan
# 0.9
# 0.9
# 0.95
# nan
# nan
# nan
# nan
# 0.9
# 0.9
# 0.95
# nan
# nan
# nan
# nan
# 0.875
# 0.875
# 0.95
# nan
# nan
# nan
# nan
# 0.875
# 0.875
# 0.95
# nan
# nan
# nan
# nan
# 0.875
# 0.875
# 0.95
# nan
# nan
# nan
# nan
# nan
# nan
# 0.95
# nan
# nan
# nan
# nan
# nan
# nan
# 0.95
# nan
# nan
# nan
# nan
# nan
# nan
# 0.95
# nan
# nan
# nan
# nan
# nan
# nan
# 0.95
# nan
# nan
# nan
# nan
# nan
# nan
# 0.95
# nan
# nan
# nan
# nan
# nan
# nan
# 0.95
# nan
# ...
